# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sridharvumma'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# To display graphs inline within the o/p cells
# %matplotlib inline

# %%
dfv=pd.read_csv("pokeman.csv")
dfv.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
dfv.set_index("Name", inplace=True)

# %%
dfv.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
dfv.drop("#", inplace=True, axis=1)

# %%
dfv.head()
# Out:
#               Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      Grass  Poison  45      49       49       65       65     45
# Ivysaur        Grass  Poison  60      62       63       80       80     60
# Venusaur       Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# Charmander      Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
type_1_data = dfv['Type 1'].value_counts().plot(kind='bar')
type_1_data

# %%
type(type_1_data)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# commented need to check again on another parameter for bar chart
plt.figure(figsize=[14,8])
plt.xlabel("Type 1 Pokemon Variants")
plt.ylabel("No. of Pokemons")
plt.title("Distribution of pokemon across various Type 1 variants")
plt.bar(type_1_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-6702deb4033e> in <module>
#       4 plt.ylabel("No. of Pokemons")
#       5 plt.title("Distribution of pokemon across various Type 1 variants")
# ----> 6 plt.bar(type_1_data)
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
type_22=dfv['Type 2'].value_counts(ascending=False).plot(kind='bar')

# %%
# groupby Type1 to get average values of attack
type_1 = dfv.groupby('Type 1')[['Attack']].mean()
type_1
# Out:
#               Attack
# Type 1
# Bug        70.971014
# Dark       88.387097
# Dragon    112.125000
# Electric   69.090909
# Fairy      61.529412
# Fighting   96.777778
# Fire       84.769231
# Flying     78.750000
# Ghost      73.781250
# Grass      73.214286
# Ground     95.750000
# Ice        72.750000
# Normal     73.469388
# Poison     74.678571
# Psychic    71.456140
# Rock       92.863636
# Steel      92.703704
# Water      74.151786

# %%
type(type_1)
# Out:
# pandas.core.frame.DataFrame

# %%
# groupby Type2 to get average values of attack
type_2 = dfv.groupby('Type 2')[['Attack']].mean()
type_2
# Out:
#               Attack
# Type 2
# Bug        90.000000
# Dark      109.800000
# Dragon     94.444444
# Electric   72.666667
# Fairy      61.608696
# Fighting  112.846154
# Fire       81.250000
# Flying     80.288660
# Ghost      84.142857
# Grass      74.160000
# Ground     89.857143
# Ice        98.000000
# Normal     52.750000
# Poison     67.588235
# Psychic    74.696970
# Rock       84.000000
# Steel      92.590909
# Water      70.142857

# %%
# reset indexes( removed groupby type as index)
type_1.reset_index(inplace=True)
type_2.reset_index(inplace=True)

# %%
type_1
# Out:
#       Type 1      Attack
# 0        Bug   70.971014
# 1       Dark   88.387097
# 2     Dragon  112.125000
# 3   Electric   69.090909
# 4      Fairy   61.529412
# 5   Fighting   96.777778
# 6       Fire   84.769231
# 7     Flying   78.750000
# 8      Ghost   73.781250
# 9      Grass   73.214286
# 10    Ground   95.750000
# 11       Ice   72.750000
# 12    Normal   73.469388
# 13    Poison   74.678571
# 14   Psychic   71.456140
# 15      Rock   92.863636
# 16     Steel   92.703704
# 17     Water   74.151786

# %%
type_1['Type 1'].unique()
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
type_2
# Out:
#       Type 2      Attack
# 0        Bug   90.000000
# 1       Dark  109.800000
# 2     Dragon   94.444444
# 3   Electric   72.666667
# 4      Fairy   61.608696
# 5   Fighting  112.846154
# 6       Fire   81.250000
# 7     Flying   80.288660
# 8      Ghost   84.142857
# 9      Grass   74.160000
# 10    Ground   89.857143
# 11       Ice   98.000000
# 12    Normal   52.750000
# 13    Poison   67.588235
# 14   Psychic   74.696970
# 15      Rock   84.000000
# 16     Steel   92.590909
# 17     Water   70.142857

# %%
type_2['Type 2'].unique()
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
# Merge two Types with left as  Type 1 and right as Type 2
merged = pd.merge(type_1, type_2, left_on='Type 1', right_on = 'Type 2')
merged
# Out:
#       Type 1    Attack_x    Type 2    Attack_y
# 0        Bug   70.971014       Bug   90.000000
# 1       Dark   88.387097      Dark  109.800000
# 2     Dragon  112.125000    Dragon   94.444444
# 3   Electric   69.090909  Electric   72.666667
# 4      Fairy   61.529412     Fairy   61.608696
# 5   Fighting   96.777778  Fighting  112.846154
# 6       Fire   84.769231      Fire   81.250000
# 7     Flying   78.750000    Flying   80.288660
# 8      Ghost   73.781250     Ghost   84.142857
# 9      Grass   73.214286     Grass   74.160000
# 10    Ground   95.750000    Ground   89.857143
# 11       Ice   72.750000       Ice   98.000000
# 12    Normal   73.469388    Normal   52.750000
# 13    Poison   74.678571    Poison   67.588235
# 14   Psychic   71.456140   Psychic   74.696970
# 15      Rock   92.863636      Rock   84.000000
# 16     Steel   92.703704     Steel   92.590909
# 17     Water   74.151786     Water   70.142857

# %%
merged.drop('Type 1', inplace=True, axis=1)
merged
# Out:
#       Attack_x    Type 2    Attack_y
# 0    70.971014       Bug   90.000000
# 1    88.387097      Dark  109.800000
# 2   112.125000    Dragon   94.444444
# 3    69.090909  Electric   72.666667
# 4    61.529412     Fairy   61.608696
# 5    96.777778  Fighting  112.846154
# 6    84.769231      Fire   81.250000
# 7    78.750000    Flying   80.288660
# 8    73.781250     Ghost   84.142857
# 9    73.214286     Grass   74.160000
# 10   95.750000    Ground   89.857143
# 11   72.750000       Ice   98.000000
# 12   73.469388    Normal   52.750000
# 13   74.678571    Poison   67.588235
# 14   71.456140   Psychic   74.696970
# 15   92.863636      Rock   84.000000
# 16   92.703704     Steel   92.590909
# 17   74.151786     Water   70.142857

# %%
merged.rename(columns={'Type 2': 'Type'}, inplace=True)
merged
# Out:
#       Attack_x      Type    Attack_y
# 0    70.971014       Bug   90.000000
# 1    88.387097      Dark  109.800000
# 2   112.125000    Dragon   94.444444
# 3    69.090909  Electric   72.666667
# 4    61.529412     Fairy   61.608696
# 5    96.777778  Fighting  112.846154
# 6    84.769231      Fire   81.250000
# 7    78.750000    Flying   80.288660
# 8    73.781250     Ghost   84.142857
# 9    73.214286     Grass   74.160000
# 10   95.750000    Ground   89.857143
# 11   72.750000       Ice   98.000000
# 12   73.469388    Normal   52.750000
# 13   74.678571    Poison   67.588235
# 14   71.456140   Psychic   74.696970
# 15   92.863636      Rock   84.000000
# 16   92.703704     Steel   92.590909
# 17   74.151786     Water   70.142857

# %%
plt.figure(figsize=(14,8))
plt.plot(merged['Type'], merged['Attack_x'], color='red')
plt.plot(merged['Type'], merged['Attack_y'], color='blue')
plt.xlabel('Types')
plt.ylabel('Mean Attack points')
plt.title("Comparison of Mean Attack Points for variants of Type 1 and Type 2")
plt.ylim((45,120))
plt.legend(labels=['Type1', 'Type2'])
plt.show()

# %%
dfv.groupby(['Type 1', 'Legendary']).size().unstack()
# Out:
# Legendary  False  True
# Type 1
# Bug         69.0    NaN
# Dark        29.0    2.0
# Dragon      20.0   12.0
# Electric    40.0    4.0
# Fairy       16.0    1.0
# Fighting    27.0    NaN
# Fire        47.0    5.0
# Flying       2.0    2.0
# Ghost       30.0    2.0
# Grass       67.0    3.0
# Ground      28.0    4.0
# Ice         22.0    2.0
# Normal      96.0    2.0
# Poison      28.0    NaN
# Psychic     43.0   14.0
# Rock        40.0    4.0
# Steel       23.0    4.0
# Water      108.0    4.0

# %% [markdown]
# # Stacked Bar Chart

# %%
dfv.groupby(['Type 1', 'Legendary']).size().unstack().plot(kind='bar',stacked=True, figsize=(15,10))
plt.xlabel('Type 1')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
dfv.groupby(['Generation','Legendary']).size()
# Out:
# Generation  Legendary
# 1           False        160
#             True           6
# 2           False        101
#             True           5
# 3           False        142
#             True          18
# 4           False        108
#             True          13
# 5           False        150
#             True          15
# 6           False         74
#             True           8
# dtype: int64

# %%
#First group Pokemons by Generation and Legendary and then calculate the counts for every variant of 
#generation based on legendary status (True or False). 
#Save this to a variable res
res = dfv.groupby(['Generation','Legendary']).size().unstack().plot(kind='bar',stacked=True, figsize=(15,10))
res

# %%
#Calculate the mean attack points for all the Pokemons and store it in a variable mean_attack
mean_attack = np.mean(dfv['Attack'])
mean_attack
# Out:
# 79.00125

# %%
#Create a dataframe named dragon consisting of only Dragon type pokemon 
#using conditional filtering (based on Type 1)
dragon = dfv[dfv['Type 1']=='Dragon']
dragon
# Out:
#                      Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Dratini              Dragon       NaN   41      64       45       50       50
# Dragonair            Dragon       NaN   61      84       65       70       70
# Dragonite            Dragon    Flying   91     134       95      100      100
# Altaria              Dragon    Flying   75      70       90       70      105
# Mega Altaria         Dragon     Fairy   75     110      110      110      105
# Bagon                Dragon       NaN   45      75       60       40       30
# Shelgon              Dragon       NaN   65      95      100       60       50
# Salamence            Dragon    Flying   95     135       80      110       80
# Mega Salamence       Dragon    Flying   95     145      130      120       90
# Latias               Dragon   Psychic   80      80       90      110      130
# Mega Latias          Dragon   Psychic   80     100      120      140      150
# Latios               Dragon   Psychic   80      90       80      130      110
# Mega Latios          Dragon   Psychic   80     130      100      160      120
# Rayquaza             Dragon    Flying  105     150       90      150       90
# Mega Rayquaza        Dragon    Flying  105     180      100      180      100
# Gible                Dragon    Ground   58      70       45       40       45
# Gabite               Dragon    Ground   68      90       65       50       55
# Garchomp             Dragon    Ground  108     130       95       80       85
# Mega Garchomp        Dragon    Ground  108     170      115      120       95
# Axew                 Dragon       NaN   46      87       60       30       40
# Fraxure              Dragon       NaN   66     117       70       40       50
# Haxorus              Dragon       NaN   76     147       90       60       70
# Druddigon            Dragon       NaN   77     120       90       60       90
# Reshiram             Dragon      Fire  100     120      100      150      120
# Zekrom               Dragon  Electric  100     150      120      120      100
# Kyurem               Dragon       Ice  125     130       90      130       90
# Kyurem Black Kyurem  Dragon       Ice  125     170      100      120       90
# Kyurem White Kyurem  Dragon       Ice  125     120       90      170      100
# Goomy                Dragon       NaN   45      50       35       55       75
# Sliggoo              Dragon       NaN   68      75       53       83      113
# Goodra               Dragon       NaN   90     100       70      110      150
# Zygarde Half Forme   Dragon    Ground  108     100      121       81       95
#
#                      Speed  Generation  Legendary
# Name
# Dratini                 50           1      False
# Dragonair               70           1      False
# Dragonite               80           1      False
# Altaria                 80           3      False
# Mega Altaria            80           3      False
# Bagon                   50           3      False
# Shelgon                 50           3      False
# Salamence              100           3      False
# Mega Salamence         120           3      False
# Latias                 110           3       True
# Mega Latias            110           3       True
# Latios                 110           3       True
# Mega Latios            110           3       True
# Rayquaza                95           3       True
# Mega Rayquaza          115           3       True
# Gible                   42           4      False
# Gabite                  82           4      False
# Garchomp               102           4      False
# Mega Garchomp           92           4      False
# Axew                    57           5      False
# Fraxure                 67           5      False
# Haxorus                 97           5      False
# Druddigon               48           5      False
# Reshiram                90           5       True
# Zekrom                  90           5       True
# Kyurem                  95           5       True
# Kyurem Black Kyurem     95           5       True
# Kyurem White Kyurem     95           5       True
# Goomy                   40           6      False
# Sliggoo                 60           6      False
# Goodra                  80           6      False
# Zygarde Half Forme      95           6       True

# %%
#Calculate the mean attack points for dragon and store it in a variable mean_dragon
mean_dragon = np.mean(dragon['Attack'])
mean_dragon
# Out:
# 112.125

# %%
#Use matplotlib's .hist() on dragon and pass arguments column='Attack', bins=8
dragon.hist(column='Attack', bins=8, figsize=(10,10))
#Use .axvline() and pass arguments x=mean_attack, color='green' to plot a vertical line 
#representing mean attack points for all the Pokemons
plt.axvline(x=mean_attack, color='green')
#Use .axvline() and pass arguments x=mean_dragon, color='black' to plot a vertical line 
#representing mean attack points for Dragon Pokemons
plt.axvline(x=mean_dragon, color='black')
# display the plot
plt.show()

# %% [markdown]
# # Scatter Plots

# %%
#First method of displaying scatter plot
plt.scatter(dfv['Attack'],dfv['Defense'])
plt.show()

# %%
# Second method of plotting scatter plot
dfv.plot.scatter(x='Attack', y='Defense')

# %%
# Create a new dataframe electric using conditional filtering for selecting pokemon
# having Type 1 as 'Electric'
# Use pandas .plot.scatter(x,y) method to draw a scatter plot with X-axes values
# as HP and Y-axes values as Attack points
electric = dfv[dfv['Type 1']== 'Electric']
electric.plot.scatter(x='HP', y='Attack')
plt.show()

# %%
# test cases 
type(electric)
# Out:
# pandas.core.frame.DataFrame

# %%
electric.shape
# Out:
# (44, 10)

# %% [markdown]
# # Sub Plots

# %%
# Initialize figure and axes
fig, (ax_1, ax_2) = plt.subplots(1,2, figsize=(20,10))
res = dfv.groupby(['Type 1', 'Legendary']).size().unstack()
res.plot(kind='bar', stacked=True, ax=ax_1)
ax_1.set_title('Stacked bar-chart with counts')

# Stacked bar-chart representing percentages
new_res = res.fillna(0)
new_res['Total'] = new_res[True] + new_res[False]
new_res[True] = (new_res[True] / new_res['Total']) * 100
new_res[False] = (new_res[False] / new_res['Total']) * 100
new_res.drop('Total', inplace=True, axis=1)
new_res.plot(kind='bar', stacked=True, ax=ax_2)
ax_2.set_title('Stacked bar-chart with percentages')
# Out:
# Text(0.5, 1.0, 'Stacked bar-chart with percentages')

# %%
# Stacked bar-chart representing counts
res = dfv.groupby(['Type 1', 'Legendary']).size().unstack()
res
# Out:
# Legendary  False  True
# Type 1
# Bug         69.0    NaN
# Dark        29.0    2.0
# Dragon      20.0   12.0
# Electric    40.0    4.0
# Fairy       16.0    1.0
# Fighting    27.0    NaN
# Fire        47.0    5.0
# Flying       2.0    2.0
# Ghost       30.0    2.0
# Grass       67.0    3.0
# Ground      28.0    4.0
# Ice         22.0    2.0
# Normal      96.0    2.0
# Poison      28.0    NaN
# Psychic     43.0   14.0
# Rock        40.0    4.0
# Steel       23.0    4.0
# Water      108.0    4.0

# %%
res.plot(kind='bar', stacked=True, ax=ax_1)

# %%
ax_1.set_title('Stacked bar-chart with counts')
# Out:
# Text(0.5, 1, 'Stacked bar-chart with counts')

# %%
# Stacked bar-chart representing percentages
new_res = res.fillna(0)

# %%
new_res['Total'] = new_res[True] + new_res[False]

# %%
new_res[True] = (new_res[True] / new_res['Total']) * 100

# %%
new_res[False] = (new_res[False] / new_res['Total']) * 100

# %%
new_res.drop('Total', inplace=True, axis=1)

# %%
new_res.plot(kind='bar', stacked=True, ax=ax_2)

# %%
ax_2.set_title('Stacked bar-chart with percentages')
# Out:
# Text(0.5, 1, 'Stacked bar-chart with percentages')

# %%
#Initialize two axes ax_1 and ax_2 using .subplots(1,2, figsize=(20,10)
#For the first plot, first group Pokemons by Generation and Legendary and then calculate the counts for every variant of generation based on legendary status (True or False).
#Save this to a variable res
#Plot a stacked bar chart in the first axes using .plot(kind='bar', stacked=True, ax=ax_1)

#For the second plot, make a new dataframe new_res by filling missing values of res with 0 using .fillna(0)
#Convert the values in this frame to percentages in a manner similar to the code snippet given in the topic
#Plot the second stacked bar-chart using ax=ax_2 inside the .plot() on new_res
fig, (ax_1, ax_2) = plt.subplots(1,2, figsize=(20,10))
res =dfv.groupby(['Generation', 'Legendary']).size().unstack()
res.plot(kind='bar', stacked=True, ax=ax_1)

new_res= res.fillna(0)
new_res['Total']= new_res[True] + new_res[False]
new_res[True] = (new_res[True] / new_res['Total']) * 100
new_res[False] = (new_res[False] / new_res['Total']) * 100
new_res.drop('Total', inplace=True, axis=1)
new_res.plot(kind='bar', stacked=True, ax=ax_2)
ax_2.set_title('Stacked bar-chart with percentages')
# Out:
# Text(0.5, 1.0, 'Stacked bar-chart with percentages')

# %%
res
# Out:
# Legendary   False  True
# Generation
# 1             160      6
# 2             101      5
# 3             142     18
# 4             108     13
# 5             150     15
# 6              74      8

# %%
# Test Cases
res.shape
# Out:
# (6, 2)

# %% [markdown]
# # Visualization for company stake holders

# %%
data=pd.read_csv('loan_prediction.csv')
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
#Save the value counts of Loan_Status in a variable called loan_status using value_counts()
#Plot a bar graph of loan_status
loan_status= data['Loan_Status'].value_counts()
loan_status.plot(kind='bar')

# %%
plt.bar(loan_status.index,loan_status)
plt.show()

# %%
type(loan_status)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# Test cases
data.iloc[25,1]
# Out:
# 'Male'

# %%
data.iloc[53,9]
# Out:
# 360.0

# %%
#Group the 'data' dataframe by Property_Area and Loan_Status and store it in a variable called 'property_and_loan'
property_and_loan = data.groupby(['Property_Area','Loan_Status'])
#Use the .size() method on 'property_and_loan' and then use .unstack() and save it back to 'property_and_loan'
property_and_loan = property_and_loan.size().unstack()
property_and_loan
# Out:
# Loan_Status     N    Y
# Property_Area
# Rural          69  110
# Semiurban      54  179
# Urban          69  133

# %%
#Group the 'data' dataframe by Property_Area and Loan_Status and store it in a variable called 'property_and_loan'
property_and_loan = data.groupby(['Property_Area','Loan_Status'])
#Use the .size() method on 'property_and_loan' and then use .unstack() and save it back to 'property_and_loan'
property_and_loan = property_and_loan.size().unstack()   
#Plot an unstacked bar plot of property_and_loan 
#(It is similar to creating a stacked bar plot except change the parameter 'stacked' to False)
property_and_loan.plot(kind='bar', stacked=False, figsize=(15,10))
#Name the x-axis as Property Area
plt.xlabel('Property Area')
#Name the y-axis as Loan Status
plt.ylabel('Loan Status')
#Rotate the labels of x-axis by 45o
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %%
#Group the 'data' dataframe by Education and Loan_Status and store it in a variable called 'education_and_loan'
education_and_loan= data.groupby(['Education', 'Loan_Status'])
#Use the .size() method on 'education_and_loan' and then use .unstack() and save it back to 'education_and_loan'
education_and_loan = education_and_loan.size().unstack()
#Plot an stacked bar plot of education_and_loan
education_and_loan.plot(kind='bar', stacked=True)
#Name the x-axis as Education Status
plt.xlabel('Education Status')
#Name the y-axis as Loan Status
plt.ylabel('Loan Status')
#Rotate the labels of x-axis by 45o
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %%
#Create a dataframe called 'graduate' which is a subset of 
#'data' dataframe with the condition "data['Education'] == 'Graduate'"
graduate=data[data['Education']== 'Graduate']
#Create a dataframe called 'not_graduate' which is a subset of 'data' 
#dataframe with the condition "data['Education'] == 'Not Graduate'"
not_graduate= data[data['Education']=='Not Graduate']
#Plot a density plot LoanAmount of 'graduate' dataframe using "Series.plot()" 
#and pass the parameter kind='density' and label='Graduate'
graduate['LoanAmount'].plot(kind='density', label='Graduate')
#Do the same for LoanAmount of 'not_graduate' dataframe but with label='Not Graduate''
not_graduate['LoanAmount'].plot(kind='density', label='Not Graduate')
##For automatic legend display
plt.legend()

# %%
#Create three subplots with (nrows = 3 , ncols = 1) and store it 
#in variable's fig ,(ax_1,ax_2,ax_3)
fig, (ax_1,ax_2, ax_3) = plt.subplots(1,3, figsize=(20,8))
#Since both are continuous variables, plot scatter plot between 'ApplicantIncome' and LoanAmount using ax_1.
#Set axis title as Applicant Income
ax_1.scatter(data['ApplicantIncome'],data['LoanAmount'])
ax_1.set(title='Applicant Income')

#Plot scatter plot between 'CoapplicantIncome' and LoanAmount using ax_2. 
#Set axis title as Coapplicant Income
ax_2.scatter(data['CoapplicantIncome'],data['LoanAmount'])
ax_2.set(title='Coapplicant Income')


#Create a new column in the dataframe called 'TotalIncome' which is a sum of the 
#values of columns ApplicantIncome and CoapplicantIncome

data['TotalIncome'] = data['ApplicantIncome']+data['CoapplicantIncome']

#Plot scatter plot between 'TotalIncome' and LoanAmount using ax_3. 
#Set axis title as Total Income
ax_3.scatter(data['TotalIncome'], data['LoanAmount'])
ax_3.set(title='Total Income')
# Out:
# [Text(0.5, 1.0, 'Total Income')]

# %%
from matplotlib import pyplot as plt
import calendar

# %% [markdown]
# # Weather Data

# %%
#Read weather data csv file with index_col as Date/Time by parsing dates
weather_data =pd.read_csv("weather_2012.csv", parse_dates=True, index_col='Date/Time')
weather_data.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# 2012-01-01 01:00:00                   Fog
# 2012-01-01 02:00:00  Freezing Drizzle,Fog
# 2012-01-01 03:00:00  Freezing Drizzle,Fog
# 2012-01-01 04:00:00                   Fog

# %%
weather_data.shape
# Out:
# (8784, 7)

# %%
#weather data grouped by day index to calculate mean for all columns
databyday = weather_data.groupby(weather_data.index.day).mean()
databyday
# Out:
#             Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# Date/Time
# 1           8.094792            3.076042    73.350694        13.510417
# 2           8.887153            3.600694    72.625000        14.906250
# 3           8.990972            2.589931    66.961806        15.329861
# 4           8.617361            3.261806    70.347222        14.031250
# 5           7.799306            1.182986    64.739583        16.013889
# 6           7.604167            0.232639    61.690972        13.520833
# 7           8.971875            0.719792    59.458333        12.100694
# 8           9.069444            2.651736    66.423611        15.774306
# 9           8.196181            2.322569    68.354167        13.965278
# 10          8.381597            2.743056    70.222222        16.218750
# 11          7.004514            0.256944    64.826389        15.222222
# 12          8.895833            1.870486    63.760417        15.232639
# 13          9.662500            2.979167    66.211806        15.576389
# 14          8.820833            2.329861    66.885417        11.958333
# 15          8.348264            3.146528    71.489583        14.052083
# 16          8.850347            3.526389    71.652778        13.319444
# 17          9.869097            4.306944    70.701389        14.711806
# 18          9.682292            2.869444    65.204861        16.284722
# 19          9.617708            3.303472    67.600694        12.208333
# 20         10.051736            3.353472    65.409722        12.965278
# 21         10.831944            4.739236    68.788194        14.611111
# 22         10.618750            5.218750    71.295139        17.357639
# 23         10.010417            3.795486    68.461806        16.378472
# 24          9.391319            2.504167    64.913194        16.059028
# 25          8.670139            2.635069    67.152778        17.225694
# 26          7.255903            0.847222    65.423611        14.309028
# 27          7.213889            1.445139    69.343750        14.833333
# 28          7.837153            1.747569    68.038194        15.774306
# 29          7.642361            1.220833    66.906250        18.750000
# 30          8.802273            1.565909    63.151515        16.666667
# 31          9.234524            3.469048    69.494048        14.327381
#
#            Visibility (km)  Stn Press (kPa)
# Date/Time
# 1                22.139236       100.777118
# 2                24.365625       100.790625
# 3                28.186111       100.961736
# 4                23.857292       100.890243
# 5                28.394444       100.980937
# 6                31.154514       101.189896
# 7                30.975347       101.122778
# 8                27.280208       100.857083
# 9                29.304167       100.941736
# 10               26.734375       100.887153
# 11               29.996181       101.264444
# 12               28.772917       101.291076
# 13               27.590278       101.244826
# 14               26.943403       101.454583
# 15               26.318056       101.528333
# 16               25.140278       101.256840
# 17               25.572222       101.102083
# 18               30.884722       101.126076
# 19               29.408681       101.268368
# 20               28.967708       101.338472
# 21               27.940972       101.030868
# 22               25.374306       100.867153
# 23               28.469097       100.736042
# 24               29.608333       100.755104
# 25               27.188889       100.843437
# 26               28.039931       101.212083
# 27               24.431597       101.097396
# 28               31.124306       101.087083
# 29               26.182292       100.898542
# 30               31.830303       100.965985
# 31               24.415476       100.663274

# %%
# groupby  indexing date/time- with month, 
#can also groupby day-- data = weather_data.groupby(weather_data.index.day).mean()
data= weather_data.groupby(weather_data.index.month).mean()
data
# Out:
#             Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# Date/Time
# 1          -7.371505          -12.294758    68.383065        18.108871
# 2          -4.225000           -9.221695    68.956897        14.837644
# 3           3.121237           -3.488575    64.862903        14.514785
# 4           7.009306           -1.934583    56.150000        17.369444
# 5          16.237769            8.080780    61.760753        12.846774
# 6          20.134028           11.738056    60.643056        14.681944
# 7          22.790054           14.595430    62.017473        11.887097
# 8          22.279301           15.644758    67.943548        13.931452
# 9          16.484444           10.757917    71.165278        14.108333
# 10         10.954973            6.533468    75.731183        15.475806
# 11          0.931389           -4.179306    69.984722        13.973611
# 12         -3.306317           -6.129032    81.299731        17.614247
#
#            Visibility (km)  Stn Press (kPa)
# Date/Time
# 1                22.100269       101.005349
# 2                25.182184       101.142414
# 3                26.177957       101.335255
# 4                31.777083       100.716833
# 5                29.418548       101.057164
# 6                32.104167       100.784222
# 7                33.655108       100.828333
# 8                30.192608       100.927097
# 9                30.603472       101.087903
# 10               25.111022       100.909368
# 11               26.077083       101.658306
# 12               19.733199       101.174409

# %%
print(calendar.month_name[1:])
# Out:
# ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
calendar_months= calendar.month_name[1:]
x_series= calendar_months
y_series= data['Temp (C)']
plt.plot(x_series, y_series)
plt.title('Temperature Trend, 2012')
plt.xlabel('Month')
plt.xticks(rotation=90)
plt.ylabel('Temp (C)')
plt.show()

# %%
#plot categorical columns
categorical_columns= weather_data.select_dtypes(include=["object"]).columns
categorical_columns
# Out:
# Index(['Weather'], dtype='object')

# %%
len(categorical_columns)
# Out:
# 1

# %% [markdown]
# # Visualising Distributions of Data
# In this section, we will see how to:
#
# Visualise univariate distributions
# Visualise bivariate distributions
# We will also start using the seaborn library for data visualisation. Seaborn is a python library built on top of matplotlib. It creates much more attractive plots than matplotlib, and is often more concise than matplotlib when you want to customize your plots, add colors, grids etc.
#
# Let's start with univariate distributions.

# %%
import seaborn as sns
sns.set_style('whitegrid')

# %%
df = pd.read_csv("market_fact.csv")
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %% [markdown]
# # Histograms and Density Plots
# Histograms and density plots show the frequency of a numeric variable along the y-axis, and the value along the x-axis. The sns.distplot() function plots a density curve. Notice that this is aesthetically better than vanilla matplotlib.

# %%
# simple density plot
sns.distplot(df['Shipping_Cost'])

# %% [raw]
# # You can also plot what is known as the rug plot which plots the actual data points as small vertical bars. The rug plot is simply specified as an argument of the distplot()

# %%
# rug = True
#plotting only a few points since rug takes a long while
sns.distplot(df['Sales'][:1000], rug=True)
plt.show()

# %% [markdown]
# Simple density plot (without the histogram bars) can be created by specifying hist=False.

# %%
sns.distplot(df['Sales'], hist=False)
plt.show()

# %% [markdown]
# ##Since seaborn uses matplotlib behind the scenes, the usual matplotlib functions work well with seaborn .
# For example, you can use subplots to plot multiple univariate distributions

# %%
#subplots

#subplot1
plt.subplot(2,2,1)
plt.title('Sales')
sns.distplot(df['Sales'])

#subplot2
plt.subplot(2,2,2)
plt.title('Profit')
sns.distplot(df['Profit'])

#subplot3
plt.subplot(2,2,3)
plt.title('Order quantity')
sns.distplot(df['Order_Quantity'])

#subplot4
plt.subplot(2,2,4)
plt.title('Shipping cost')
sns.distplot(df['Shipping_Cost'])

plt.show()

# %% [markdown]
# # Boxplots
# Boxplots are a great way to visualise univariate data because they represent statistics such as the 25th percentile, 50th percentile, etc

# %%
# box plots show 25th percentile, 50th Percentile, 75th percentile and also min, max values 
sns.boxplot(y = df['Order_Quantity'])
plt.title('Order Quantity')
plt.show()

# %% [markdown]
# # Visualising Bivariate Distributions
# Bivariate distributions are simply two univariate distributions plotted on x and y axes respectively. They help you observe the relationship between the two variables.
#
# They are also called joint distributions and are created using sns.jointplot()

# %%
# joint plots of Profit and Sales
sns.jointplot(df['Sales'], df['Profit'])
plt.show()

# %% [markdown]
# #Notice that both the distributions are heavily skewed and all the points seem to be concentrated in one region. That is because of some extreme values of Profits and Sales which matplotlib is trying to accomodate in the limited space of the plot.
#
# Let's remove that point and plot again.

# %%
# remove points having extreme values
df1 = df[(df.Profit < 10000) & (df.Sales < 20000)]
sns.jointplot(df1['Sales'], df1['Profit'])
plt.show()

# %%
# Hex plot
df3 = df[(df.Profit < 100) & (df.Profit > -100) & (df.Sales < 200)]
sns.jointplot(df3['Sales'],df3['Profit'], kind="hex", color='k')
plt.show()

# %% [markdown]
# # Plotting Pairwise Relationships
# You'll find it helpful to plot pairwise relationships between multiple numeric variables. For e.g., here we have taken the prices of some popular cryptocurrencies such as bitcoin, litecoin, ethereum, monero, neo, quantum and ripple.
#
# Now, the crypto enthusiasts would know that the prices of these currencies vary with each other. If bitcoin goes up, the others will likely follow suit, etc.
#
# Now, say you want to trade in some currencies. Given a set of cryptocurrencies, how will you decide when and which one to buy/sell? It will be helpful to analyse past data and identify some trends in these currencies.

# %%
btc = pd.read_csv("bitcoin_price.csv")
ether = pd.read_csv("ethereum_price.csv")
ltc = pd.read_csv("litecoin_price.csv")
monero = pd.read_csv("monero_price.csv")
neo = pd.read_csv("neo_price.csv")
quantum = pd.read_csv("qtum_price.csv")
ripple = pd.read_csv("ripple_price.csv")

# %%
#Adding suffixes to column names so that joins are easy
btc.columns = btc.columns.map(lambda x: str(x)+'_btc')
ether.columns = ether.columns.map(lambda x: str(x) + '_et')
ltc.columns = ltc.columns.map(lambda x: str(x) + '_ltc')
monero.columns = monero.columns.map(lambda x: str(x) + '_mon')
neo.columns = neo.columns.map(lambda x: str(x) + '_neo')
quantum.columns = quantum.columns.map(lambda x: str(x) + '_qt')
ripple.columns = ripple.columns.map(lambda x: str(x) + '_rip')

# %%
ripple.shape
# Out:
# (1557, 7)

# %%
#merging all the files by date
# since how= inner is specified only common date columns of all crypto coins are considered
#inspite of btc shape being(1655,7),ether shape (824,7),ltc shape(1655,7), monero shape(1266,7)
# neo shape(425,7),quantum shape(168,7), ripple shape(1557,7), the smallest of all quantum is considered and hence the
# size of the resultant dataframe crypto is 168 rows with 7x7= 49 columns
m1 = pd.merge(btc,ether,how='inner', left_on='Date_btc', right_on='Date_et')
m2 = pd.merge(m1, ltc, how="inner", left_on="Date_btc", right_on="Date_ltc")
m3 = pd.merge(m2, monero, how="inner", left_on="Date_btc", right_on="Date_mon")
m4 = pd.merge(m3, neo, how="inner", left_on="Date_btc", right_on="Date_neo")
m5 = pd.merge(m4, quantum, how="inner", left_on="Date_btc", right_on="Date_qt")
crypto = pd.merge(m5, ripple, how="inner", left_on="Date_btc", right_on="Date_rip")

# %%
crypto.shape
# Out:
# (168, 49)

# %%
crypto.head()
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc       Date_et  Open_et  High_et  ...  Close_qt  \
# 0  117,056,000,000  Nov 07, 2017   298.57   304.84  ...     11.21
# 1  123,379,000,000  Nov 06, 2017   296.43   305.42  ...     10.44
# 2  123,388,000,000  Nov 05, 2017   300.04   301.37  ...     10.13
# 3  119,376,000,000  Nov 04, 2017   305.48   305.48  ...     10.05
# 4  118,084,000,000  Nov 03, 2017   288.50   308.31  ...     10.38
#
#      Volume_qt Market Cap_qt      Date_rip  Open_rip  High_rip   Low_rip  \
# 0  122,951,000   760,320,000  Nov 07, 2017  0.205103  0.211375  0.203978
# 1  116,937,000   745,802,000  Nov 06, 2017  0.201967  0.208662  0.201410
# 2   49,288,500   739,113,000  Nov 05, 2017  0.203274  0.205124  0.201117
# 3   35,477,100   759,110,000  Nov 04, 2017  0.208083  0.208479  0.202133
# 4   55,018,600   719,701,000  Nov 03, 2017  0.206205  0.228026  0.201728
#
#    Close_rip   Volume_rip Market Cap_rip
# 0   0.210354  114,073,000  7,902,920,000
# 1   0.205990  102,233,000  7,782,080,000
# 2   0.202055   46,959,000  7,832,450,000
# 3   0.203750   74,013,200  8,017,770,000
# 4   0.208133  373,402,000  7,945,410,000
#
# [5 rows x 49 columns]

# %%
## Subsetting only the closing prices column for plotting
curr= crypto[['Close_btc', 'Close_et',  'Close_ltc', "Close_mon", "Close_neo", "Close_qt",'Close_rip']]
curr.head()
# Out:
#    Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt  Close_rip
# 0    7144.38    294.66      61.30      99.76      26.23     11.21   0.210354
# 1    7022.76    298.89      55.17     102.92      26.32     10.44   0.205990
# 2    7407.41    296.26      54.75      86.35      26.38     10.13   0.202055
# 3    7379.95    300.47      55.04      87.30      26.49     10.05   0.203750
# 4    7207.76    305.71      56.18      87.99      26.82     10.38   0.208133

# %%
curr.shape
# Out:
# (168, 7)

# %% [markdown]
# # Pairwise Scatter Plots
# Now, since we have multiple numeric variables, sns.pairplot() is a good choice to plot all of them in one figure.

# %%
#pairplot
sns.pairplot(curr)
plt.show()

# %%
#correlation can be checked for using df.corr, correlation matrix is displayed below
corrvalues= curr.corr()
corrvalues
# Out:
#            Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt  \
# Close_btc   1.000000  0.449322   0.657963   0.697058   0.734797  0.381921
# Close_et    0.449322  1.000000   0.490281   0.539489   0.481910  0.791373
# Close_ltc   0.657963  0.490281   1.000000   0.793368   0.641385  0.447711
# Close_mon   0.697058  0.539489   0.793368   1.000000   0.668514  0.518419
# Close_neo   0.734797  0.481910   0.641385   0.668514   1.000000  0.556858
# Close_qt    0.381921  0.791373   0.447711   0.518419   0.556858  1.000000
# Close_rip  -0.198174  0.332148  -0.186893  -0.085544  -0.375406  0.292045
#
#            Close_rip
# Close_btc  -0.198174
# Close_et    0.332148
# Close_ltc  -0.186893
# Close_mon  -0.085544
# Close_neo  -0.375406
# Close_qt    0.292045
# Close_rip   1.000000

# %% [raw]
# # Notice that quantum and etherium are highly correlated(0.791), like wise ltc and monero are highly correlated(0.793) , like wise neo and btc are highly correlated(0.73)

# %% [markdown]
# # Heatmaps
# It will be helpful to visualise the correlation matrix itself using sns.heatmap().

# %%
#figure size
plt.figure(figsize=(10,8))
sns.heatmap(corrvalues,cmap="YlGnBu", annot=True)
plt.show()
