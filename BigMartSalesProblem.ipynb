# %%
import os
os.getcwd()
os.chdir("E:\\datasciencecommon\\BigMartSalesProblem\\")
os.getcwd()
os.listdir()
# Out:
# ['sample_submission_8RXa3c6.csv',
#  'test_AbJTz2l.csv',
#  'train.csv',
#  'train_excel.xlsx',
#  'train_v9rqX0R.csv']

# %%
import pandas as pd

# %%
dataframe=pd.read_csv("train_v9rqX0R.csv")

# %%
#starts with zero index
dataframe.head(6)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# ...

# %%
dataframe.to_csv("train.csv")

# %%
dataframe.to_excel("train_excel.xlsx")

# %%
dataframe.shape
# Out:
# (8523, 12)

# %%
dataframe.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
dataframe['Item_Outlet_Sales']
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
#pass the columns list to the dataframe to display a list of columns
dataframe[['Item_Weight', 'Item_Fat_Content']]
# Out:
#       Item_Weight Item_Fat_Content
# 0           9.300          Low Fat
# 1           5.920          Regular
# 2          17.500          Low Fat
# 3          19.200          Regular
# 4           8.930          Low Fat
# ...           ...              ...
# 8518        6.865          Low Fat
# 8519        8.380          Regular
# 8520       10.600          Low Fat
# 8521        7.210          Regular
# 8522       14.800          Low Fat
#
# [8523 rows x 2 columns]

# %%
#selecting rows by their positions
# equivalent command is dataframe.head(5)
dataframe.iloc[:5]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#selecting columns by their positions(first :is for rows and second : is for columns)
#select the first two columns here
dataframe.iloc[:,:4]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              NCD19        8.930          Low Fat         0.000000
# 4              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 4645           FDF53       20.750              reg         0.083607
# 4646           FDF22        6.865          Low Fat         0.056783
# 4647           NCJ29       10.600          Low Fat         0.035186
# 4648           FDN46        7.210          Regular         0.145221
# 4649           DRG01       14.800          Low Fat         0.044878
#
# [4650 rows x 4 columns]

# %%
outlet_establishment_year_2009= dataframe[dataframe["Outlet_Establishment_Year"]==2009]
outlet_establishment_year_2009
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 4              FDP36       10.395          Regular         0.000000
# 12             NCB42       11.800          Low Fat         0.008596
# 20             NCS17       18.600          Low Fat         0.080829
# 21             FDP33       18.700          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 4637           DRF37       17.250          Low Fat         0.084676
# 4640           FDF05       17.500          Low Fat         0.026980
# 4643           FDH24       20.700          Low Fat         0.021518
# 4644           NCJ19       18.600          Low Fat         0.118661
# 4648           FDN46        7.210          Regular         0.145221
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# ...

# %%
import numpy as np

# %%
dataframe=dataframe.dropna(how="any")

# %%
#(8523, 12) is the shape before dropping rows containing "any" in the dataset
dataframe.shape
# Out:
# (4650, 12)

# %%
sorted_data = dataframe.sort_values(by='Outlet_Establishment_Year')

# %%
sorted_data.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2812           FDR60        14.30          Low Fat         0.130307
# 5938           NCJ06        20.10          Low Fat         0.034624
# 3867           FDY38        13.60          Regular         0.119077
# 1307           FDB37        20.25          Regular         0.022922
# 5930           NCA18        10.10          Low Fat         0.056031
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2812  Baking Goods   75.7328            OUT013                       1987
# 5938     Household  118.9782            OUT013                       1987
# 3867         Dairy  231.2300            OUT013                       1987
# 1307  Baking Goods  240.7538            OUT013                       1987
# 5930     Household  115.1492            OUT013                       1987
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
dataframe.sort_values(by='Outlet_Establishment_Year', ascending=False, inplace=True)
dataframe[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2825           FDL16        12.85          Low Fat         0.169139
# 7389           NCD42        16.50          Low Fat         0.012689
# 2165           DRJ39        20.25          Low Fat         0.036474
# 2162           FDR60        14.30          Low Fat         0.130946
# 2158           FDM58        16.85          Regular         0.080015
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 2825        Frozen Foods   46.4060            OUT018
# 7389  Health and Hygiene   39.7506            OUT018
# 2165               Dairy  218.3482            OUT018
# 2162        Baking Goods   76.7328            OUT018
# 2158         Snack Foods  111.8544            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2825                       2009      Medium               Tier 3
# 7389                       2009      Medium               Tier 3
# ...

# %%
# Read fresh train data again
dataframe=pd.read_csv("train_v9rqX0R.csv")
dataframe=dataframe.dropna(how="any")
dataframe.sort_values(by=['Outlet_Establishment_Year','Item_Outlet_Sales'],ascending=False)[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 43             FDC02        21.35          Low Fat         0.069103
# 2803           FDU51        20.20          Regular         0.096907
# 641            FDY51        12.50          Low Fat         0.081465
# 2282           NCX30        16.70          Low Fat         0.026729
# 2887           FDR25        17.00          Regular         0.140090
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 43       Canned  259.9278            OUT018                       2009
# 2803       Meat  175.5028            OUT018                       2009
# 641        Meat  220.7798            OUT018                       2009
# 2282  Household  248.4776            OUT018                       2009
# 2887     Canned  265.1884            OUT018                       2009
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
dataframe.sort_values(by=['Item_Outlet_Sales','Outlet_Establishment_Year'],ascending=False, inplace=True)
dataframe[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4888           FDF39       14.850          Regular         0.019495
# 4289           NCM05        6.825          Low Fat         0.059847
# 6409           FDA21       13.650          Low Fat         0.035931
# 4991           NCQ53       17.600          Low Fat         0.018905
# 5752           FDI15       13.800          Low Fat         0.141326
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 4888               Dairy  261.2910            OUT013
# 4289  Health and Hygiene  262.5226            OUT046
# 6409         Snack Foods  184.4924            OUT013
# 4991  Health and Hygiene  234.6590            OUT046
# 5752               Dairy  265.0884            OUT035
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 4888                       1987        High               Tier 3
# 4289                       1997       Small               Tier 1
# ...

# %%
dataframe.sort_index(inplace=True)
dataframe[:5]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
from scipy.stats import mode

# %%
#accessing row wise
dataframe.apply(lambda x: x)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
#accessing first row
dataframe.apply(lambda x: x[0])
# Out:
# Item_Identifier                          FDA15
# Item_Weight                                9.3
# Item_Fat_Content                       Low Fat
# Item_Visibility                      0.0160473
# Item_Type                                Dairy
# Item_MRP                               249.809
# Outlet_Identifier                       OUT049
# Outlet_Establishment_Year                 1999
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 1
# Outlet_Type                  Supermarket Type1
# Item_Outlet_Sales                      3735.14
# dtype: object

# %%
#access first column by index
dataframe.apply(lambda x: x[0], axis=1)
# Out:
# 0       FDA15
# 1       DRC01
# 2       FDN15
# 4       NCD19
# 5       FDP36
#         ...
# 8517    FDF53
# 8518    FDF22
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Length: 4650, dtype: object

# %%
#access by column name
dataframe.apply(lambda x: x['Item_Fat_Content'], axis=1)
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 4       Low Fat
# 5       Regular
#          ...
# 8517        reg
# 8518    Low Fat
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Length: 4650, dtype: object

# %%
dataframe["Item_MRP"][:5]
# Out:
# 0    249.8092
# 1     48.2692
# 2    141.6180
# 4     53.8614
# 5     51.4008
# Name: Item_MRP, dtype: float64

# %%
#clip price if it is greater then 200
def clip_price(price):
    if price > 200:
        price =200
    return price

#after clipping
dataframe['Item_MRP'].apply(lambda x: clip_price(x))[:5]
# Out:
# 0    200.0000
# 1     48.2692
# 2    141.6180
# 4     53.8614
# 5     51.4008
# Name: Item_MRP, dtype: float64

# %%
dataframe['Outlet_Location_Type'][:5]
# Out:
# 0    Tier 1
# 1    Tier 3
# 2    Tier 1
# 4    Tier 3
# 5    Tier 3
# Name: Outlet_Location_Type, dtype: object

# %%
#label encode city type
def label_encode(city):
    if city =='Tier 1':
        label= 0
    elif city =='Tier 2':
        label = 1
    else:
        label =2
    return label

dataframe['Outlet_Location_Type']=dataframe['Outlet_Location_Type'].apply(label_encode)

# %%
dataframe[:5]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size  Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
#lets read the data again
dataframe=pd.read_csv("train_v9rqX0R.csv")
dataframe=dataframe.dropna(how='any')
dataframe=dataframe.reset_index(drop=True)
dataframe.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           NCD19        8.930          Low Fat         0.000000
# 4           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 3     Household   53.8614            OUT013                       1987
# 4  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
#Aggregating data
#groupby
#crosstab
#pivot table

price_by_item = dataframe.groupby('Item_Type')

price_by_item.first()
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Baking Goods                    FDP36       10.395          Regular
# Breads                          FDW11       12.600          Low Fat
# Breakfast                       FDP49        9.000          Regular
# Canned                          FDC02       21.350          Low Fat
# Dairy                           FDA15        9.300          Low Fat
# Frozen Foods                    FDR28       13.850          Regular
# Fruits and Vegetables           FDY07       11.800          Low Fat
# Hard Drinks                     DRJ59       11.650          low fat
# Health and Hygiene              NCB42       11.800          Low Fat
# Household                       NCD19        8.930          Low Fat
# Meat                            FDN15       17.500          Low Fat
# Others                          NCM43       14.500          Low Fat
# Seafood                         FDH21       10.395          Low Fat
# ...

# %%
price_by_item.Item_MRP.mean()
# Out:
# Item_Type
# Baking Goods             125.795653
# Breads                   141.300639
# Breakfast                134.090683
# Canned                   138.551179
# Dairy                    149.481471
# Frozen Foods             140.095830
# Fruits and Vegetables    145.418257
# Hard Drinks              140.102908
# Health and Hygiene       131.437324
# Household                149.884244
# Meat                     140.279344
# Others                   137.640870
# Seafood                  146.595782
# Snack Foods              147.569955
# Soft Drinks              130.910182
# Starchy Foods            151.256747
# Name: Item_MRP, dtype: float64

# %%
multiple_groups = dataframe.groupby(['Item_Type','Item_Fat_Content'])
multiple_groups.first()
# Out:
#                                Item_Identifier  Item_Weight  Item_Visibility  \
# Item_Type     Item_Fat_Content
# Baking Goods  LF                         FDP24       20.600         0.083133
#               Low Fat                    FDG24        7.975         0.014619
#               Regular                    FDP36       10.395         0.000000
#               low fat                    FDK48        7.445         0.000000
#               reg                        FDT24       12.350         0.186148
# ...                                        ...          ...              ...
# Starchy Foods LF                         FDB11       16.000         0.060797
#               Low Fat                    FDB11       16.000         0.060837
#               Regular                    FDB35       12.300         0.064565
#               low fat                    FDE47       14.150         0.037877
#               reg                        FDF11       10.195         0.017703
#
# ...

# %%
#generate crosstab of outlet size and outlet location type
pd.crosstab(dataframe['Outlet_Size'], dataframe['Outlet_Location_Type'], margins=True)
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3   All
# Outlet_Size
# High                       0       0     932   932
# Medium                   930       0     928  1858
# Small                    930     930       0  1860
# All                     1860     930    1860  4650

# %%
#create pivot table, mean value of sales is shown
pd.pivot_table(dataframe, index=['Outlet_Establishment_Year'], values='Item_Outlet_Sales')
# Out:
#                            Item_Outlet_Sales
# Outlet_Establishment_Year
# 1987                             2298.995256
# 1997                             2277.844267
# 1999                             2348.354635
# 2004                             2438.841866
# 2009                             1995.498739

# %%
#create another pivot Table
pd.pivot_table(dataframe, index=['Outlet_Establishment_Year','Outlet_Location_Type','Outlet_Size'], values='Item_Outlet_Sales')
# Out:
#                                                             Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Location_Type Outlet_Size
# 1987                      Tier 3               High               2298.995256
# 1997                      Tier 1               Small              2277.844267
# 1999                      Tier 1               Medium             2348.354635
# 2004                      Tier 2               Small              2438.841866
# 2009                      Tier 3               Medium             1995.498739

# %%
pd.pivot_table(dataframe, index=['Outlet_Establishment_Year','Outlet_Location_Type','Outlet_Size'], values='Item_Outlet_Sales', aggfunc=[np.mean,np.median,min, max,np.std])
# Out:
#                                                                         mean  \
#                                                            Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Location_Type Outlet_Size
# 1987                      Tier 3               High              2298.995256
# 1997                      Tier 1               Small             2277.844267
# 1999                      Tier 1               Medium            2348.354635
# 2004                      Tier 2               Small             2438.841866
# 2009                      Tier 3               Medium            1995.498739
#
#                                                                       median  \
#                                                            Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Location_Type Outlet_Size
# 1987                      Tier 3               High                2050.6640
# 1997                      Tier 1               Small               1945.8005
# ...

# %%
data ={'name':['Kunal','Ankit','Purva','Pranav', 'Sunil'],
        'age':[42,52,36,24,73],
        'Testscore_1':[4,24,31,2,3],
        'Testscore_2':[25,94,57,62,70]}
df = pd.DataFrame(data, columns = ['name','age','Testscore_1','Testscore_2'])


df
# Out:
#      name  age  Testscore_1  Testscore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
df['age'].sum()
# Out:
# 227

# %%
df['Testscore_1'].mean()
# Out:
# 12.8

# %%
df['Testscore_1'].cumsum()
# Out:
# 0     4
# 1    28
# 2    59
# 3    61
# 4    64
# Name: Testscore_1, dtype: int64

# %%
df['Testscore_1'].describe()
# Out:
# count     5.000000
# mean     12.800000
# std      13.663821
# min       2.000000
# 25%       3.000000
# 50%       4.000000
# 75%      24.000000
# max      31.000000
# Name: Testscore_1, dtype: float64

# %%
df['Testscore_1'].count()
# Out:
# 5

# %%
df['Testscore_1'].min()
# Out:
# 2

# %%
df['Testscore_1'].max()
# Out:
# 31

# %%
df['Testscore_1'].median()
# Out:
# 4.0

# %%
df['Testscore_1'].var()
# Out:
# 186.7

# %%
df['Testscore_1'].std()
# Out:
# 13.663820841916802

# %%
df['Testscore_1'].skew()
# Out:
# 0.7433452457326751

# %%
df['Testscore_1'].kurt()
# Out:
# -2.4673543738411547

# %%
df.corr()
# Out:
#                   age  Testscore_1  Testscore_2
# age          1.000000    -0.105651     0.328852
# Testscore_1 -0.105651     1.000000     0.378039
# Testscore_2  0.328852     0.378039     1.000000

# %%
df.cov()
# Out:
#                 age  Testscore_1  Testscore_2
# age          340.80       -26.65       151.20
# Testscore_1  -26.65       186.70       128.65
# Testscore_2  151.20       128.65       620.30

# %%
df.rename(columns={'score_1':'Testscore_1','score_2':'Testscore_2'}, inplace=True)
# df.rename(columns={0 : 'title',1 : 'author'},inplace=True)

# %%
df
# Out:
#      name  age  Testscore_1  Testscore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
df_ages=pd.DataFrame({'age':np.random.randint(21,51,8)})
df_ages
# Out:
#    age
# 0   43
# 1   44
# 2   21
# 3   49
# 4   32
# 5   46
# 6   22
# 7   47

# %%
df_ages['age_bins']=pd.cut(x=df_ages['age'], bins=[20,29,39,49])
df_ages
# Out:
#    age  age_bins
# 0   43  (39, 49]
# 1   44  (39, 49]
# 2   21  (20, 29]
# 3   49  (39, 49]
# 4   32  (29, 39]
# 5   46  (39, 49]
# 6   22  (20, 29]
# 7   47  (39, 49]

# %%
df_ages['age_bins'].unique()
# Out:
# [(39, 49], (20, 29], (29, 39]]
# Categories (3, interval[int64]): [(20, 29] < (29, 39] < (39, 49]]

# %%
df_ages['age_by_decade']=pd.cut(x=df_ages['age'],bins=[20,29,39,49],labels=['20s','30s','40s'])
df_ages
# Out:
#    age  age_bins age_by_decade
# 0   43  (39, 49]           40s
# 1   44  (39, 49]           40s
# 2   21  (20, 29]           20s
# 3   49  (39, 49]           40s
# 4   32  (29, 39]           30s
# 5   46  (39, 49]           40s
# 6   22  (20, 29]           20s
# 7   47  (39, 49]           40s

# %%
#creating dummy data
df1=pd.DataFrame({'A':['A0','A1','A2','A3'],
                'B':['B0','B1','B2','B3'],
                 'C':['C0','C1','C2','C3'],
                 'D':['D0','D1','D2','D3']},index=[0,1,2,3])
df2=pd.DataFrame({'A':['A4','A5','A6','A7'],
                'B':['B4','B5','B6','B7'],
                 'C':['C4','C5','C6','C7'],
                 'D':['D4','D5','D6','D7']},index=[4,5,6,7])
result=pd.concat([df1,df2])
result
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
result=pd.concat([df1,df2], keys=['x','y'])
result
# Out:
#       A   B   C   D
# x 0  A0  B0  C0  D0
#   1  A1  B1  C1  D1
#   2  A2  B2  C2  D2
#   3  A3  B3  C3  D3
# y 4  A4  B4  C4  D4
#   5  A5  B5  C5  D5
#   6  A6  B6  C6  D6
#   7  A7  B7  C7  D7

# %%
result.loc['y']
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
result=pd.concat([df1,df2], axis=1)
result
# Out:
#      A    B    C    D    A    B    C    D
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 3   A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   A4   B4   C4   D4
# 5  NaN  NaN  NaN  NaN   A5   B5   C5   D5
# 6  NaN  NaN  NaN  NaN   A6   B6   C6   D6
# 7  NaN  NaN  NaN  NaN   A7   B7   C7   D7

# %%
result=pd.concat([df1,df2], axis=1,join='outer')
result
# Out:
#      A    B    C    D    A    B    C    D
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 3   A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   A4   B4   C4   D4
# 5  NaN  NaN  NaN  NaN   A5   B5   C5   D5
# 6  NaN  NaN  NaN  NaN   A6   B6   C6   D6
# 7  NaN  NaN  NaN  NaN   A7   B7   C7   D7

# %%
result=pd.concat([df1,df2], axis=0,join='inner')
result
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df4=pd.DataFrame({'B':['B2','B3','B6','B7'],
                  'D':['D2','D3','D6','D7'],
                  'F':['F2','F3','F6','F7']}, index=[2,3,6,7])
result=pd.concat([df1, df4],axis=1,sort=False)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result=pd.concat([df1, df4],axis=1,join='inner')
result
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %%
result=pd.concat([df1, df4],axis=1,join='outer')
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result=pd.concat([df1, df4],axis=0,join='inner')
result
# Out:
#     B   D
# 0  B0  D0
# 1  B1  D1
# 2  B2  D2
# 3  B3  D3
# 2  B2  D2
# 3  B3  D3
# 6  B6  D6
# 7  B7  D7

# %%
df_a=pd.DataFrame({'subject_id':['1','2','3','4','5'],
                   'first_name':['Alex','Amy','Allen','Alice','Ayoung'],
                   'last_name':['Anderson','Ackerman','Ali','Aoni','Atiches']})
df_b=pd.DataFrame({'subject_id':['4','5','6','7','8'],
                   'first_name':['Billy','Brian','Bran','Bryce','Betty'],
                   'last_name':['Bonder','Black','Balwner','Brice','Btisan']})
df_c=pd.DataFrame({'subject_id':['1','2','3','4','5','7','8','9','10','11'],
                   'test_id':[51,15,15,61,16,14,15,1,61,16]
                   })
# there will always be a reference column for merge to happen,i.e on which column does merge happen

# %%
pd.merge(df_a,df_c, on='subject_id', how='inner')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %%
pd.merge(df_a,df_c, on='subject_id',how='outer')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16
# 5          7        NaN       NaN       14
# 6          8        NaN       NaN       15
# 7          9        NaN       NaN        1
# 8         10        NaN       NaN       61
# 9         11        NaN       NaN       16

# %%
pd.merge(df_a,df_b, on='subject_id',how='outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %%
pd.merge(df_a,df_b, on='subject_id', how='inner')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
pd.merge(df_a,df_b, on='subject_id',how='right')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black
# 2          6          NaN         NaN         Bran     Balwner
# 3          7          NaN         NaN        Bryce       Brice
# 4          8          NaN         NaN        Betty      Btisan

# %%
pd.merge(df_a,df_b, on='subject_id',how='left')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
